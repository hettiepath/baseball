# %% [markdown]
# # read_file() : 파일 읽기
# - input : .csv 혹은 .xlsx
# - output : pandas dataframe
#
# # preprocess() : 선수명에 따라 연도별 능력 변수 추출
# - 선수명 따라 pivot table 생성 후, 연도별 능력 값 추출
#
# # 모델에서 적용될 값
# - input_dim
# - output_dim
# - lr
# - shared_network
# - activation
# - loss
# - num_steps

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
# %matplotlib inline
import math
from matplotlib import rc, font_manager
# 한글 처리를 위해 폰트 설정
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc("font", family=font_name)

# %%
# 도수분포표를 이용한 막대 그래프 그리기
ex1 = pd.read_excel("C:/netsong7/statistics/frequency_py.xlsx", index_col=0)
ex1

beforeMax = ex1.loc[:, "복용 전"].max()
beforeMin = ex1.loc[:, "복용 전"].min()

afterMax = ex1.loc[:, "복용 후"].max()
afterMin = ex1.loc[:, "복용 후"].min()

print(beforeMax, ", ", beforeMin, ", ", afterMax, ", ", afterMin)

step = [n for n in range(50, 90, 5)]
step

plt.hist(x=ex1["복용 전"], bins=step, rwidth=0.6)
sns.set_style("whitegrid")
plt.show()
